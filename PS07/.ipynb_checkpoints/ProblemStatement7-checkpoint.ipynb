# %%
import pandas as pd
import numpy as np
import warnings 
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HousingData.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.shape
# Out:
# (506, 14)

# %%
df.size
# Out:
# 7084

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(25, 15))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.boxplot(v,ax=axs[index],)
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
#Let's remove MEDV outliers (MEDV = 50.0) before plotting more distributions
df = df[~(df['MEDV'] >= 50.0)]
print(np.shape(df))
# Out:
# (490, 14)

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
#The histogram also shows that columns CRIM, ZN, B has highly skewed distributions. 
#Also MEDV looks to have a normal distribution (the predictions) and other colums seem to have 
#norma or bimodel ditribution of data except CHAS (which is a discrete variable).

#Now let's plot the pairwise correlation on data

# %%
for k,v in df.items():
    sns.distplot(x=v)
    plt.title(k)
    plt.show()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr().abs(),annot=True)
# Out:
# <Axes: >

# %%
#From correlation matrix, we see TAX and RAD are highly correlated features. 
#The columns LSTAT, INDUS, RM, TAX, NOX, PTRAIO has a correlation score above 0.5 with MEDV which is a good 
#indication of using as predictors. Let's plot these columns against MEDV.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='TAX',y='RAD',hue='MEDV',data=df)
# Out:
# <Axes: xlabel='TAX', ylabel='RAD'>

# %%
from sklearn.preprocessing import MinMaxScaler
cols = df.columns
df_copy = df.copy()
# apply normalization techniques
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled,columns=cols)
print("Scaled Dataset Using MinMaxScaler")
df_scaled.head()
# Out:
# Scaled Dataset Using MinMaxScaler
#        CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  0.000000  0.18  0.058148   0.0  0.314815  0.577505  0.641607  0.268711
# 1  0.000236  0.00  0.234444   0.0  0.172840  0.547998  0.782698  0.348524
# 2  0.000236  0.00  0.234444   0.0  0.172840  0.694386  0.599382  0.348524
# 3  0.000293  0.00  0.053333   0.0  0.150206  0.658555  0.441813  0.448173
# 4  0.000705  0.00  0.053333   0.0  0.150206  0.687105  0.528321  0.448173
#
#         RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0  0.000000  0.208015  0.287234  1.000000  0.083356  0.433790
# 1  0.043478  0.104962  0.553191  1.000000  0.198944  0.378995
# 2  0.043478  0.104962  0.553191  0.989737  0.056960  0.678082
# 3  0.086957  0.066794  0.648936  0.994276  0.026674  0.648402
# 4  0.086957  0.066794  0.648936  1.000000       NaN  0.712329

# %%
df.isna().sum()
# Out:
# CRIM       19
# ZN         19
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        18
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
for i in df_scaled.columns[df_scaled.isna().any(axis=0)]:
    df_scaled[i].fillna(df_scaled[i].mean(),inplace=True)
df_scaled.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
X = df_scaled[['LSTAT','RM']]
Y = df_scaled['MEDV']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=47)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (392, 2)
# (98, 2)
# (392,)
# (98,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# model evaluation for training set
from sklearn.metrics import r2_score
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.10848273174688101
# R2 score is 0.636015703437148
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 0.1054787384634212
# R2 score is 0.6476227742899077

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
newdf = sns.load_dataset('iris')
newdf['species'] = labelencoder.fit_transform(newdf['species'])

# %%
newdf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
from scipy import stats
fig, axs = plt.subplots(ncols=3,nrows=2,figsize=(25,15))
index = 0
axs = axs.flatten()
for col, v in newdf.items():
    sns.boxplot(y=col,ax=axs[index],data=newdf)
    index += 1
plt.show()

# %%
sns.heatmap(newdf.corr().abs(),annot=True)
plt.show()

# %%
newdf.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
X = newdf[['petal_length','petal_width','sepal_length']]
Y = newdf['species']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=47)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (120, 3)
# (120,)
# (30, 3)
# (30,)

# %%
from sklearn.linear_model import LinearRegression
lin_mod = LinearRegression()

lin_mod.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lin_mod.predict(X_test)
# Out:
# array([-0.09766924, -0.0796541 ,  1.18622955,  0.07163313, -0.0205322 ,
#         1.98827149,  1.17575678,  1.98539755,  1.20047351, -0.00843432,
#         1.69326764,  0.01628241,  1.16151282,  1.83617171,  1.6019431 ,
#         1.88647418,  0.91426086, -0.05116619, -0.0310332 , -0.16134665,
#         2.04910319,  1.29101372,  1.79303179,  1.46110041,  1.89401655,
#         2.05867872,  1.33751678,  2.10607901,  0.01251122,  0.16379845])

# %%
from sklearn.metrics import r2_score,mean_squared_error

y_test_predict = lin_mod.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 0.18888973130838646
# R2 score is 0.9533941980633106

# %%
sns.histplot(data=newdf, x="sepal_length" ,bins=15, hue=)
plt.show()
